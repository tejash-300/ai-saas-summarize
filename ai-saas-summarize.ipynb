# %%
# !pip install fastapi uvicorn transformers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 4.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.5/71.5 kB 5.8 MB/s eta 0:00:00
# ...

# %%
from huggingface_hub import login
login("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")

# %%
# !ngrok config add-authtoken 2sj9Z1ebBXClcjPaWZ9TkflLyB5_2Tb2UBhQTLCdRKPhNpn69
# Out:
# Authtoken saved to configuration file: /root/.config/ngrok/ngrok.yml

# %%
# !pip install fastapi uvicorn nest-asyncio transformers pyngrok

from fastapi import FastAPI
from transformers import pipeline
import uvicorn
import nest_asyncio
from pyngrok import ngrok

# Authenticate Ngrok
ngrok.set_auth_token("2sj9Z1ebBXClcjPaWZ9TkflLyB5_2Tb2UBhQTLCdRKPhNpn69")  # Replace with your token

# Initialize FastAPI app
app = FastAPI()

# Load BART model for text summarization
summarizer = pipeline("summarization", model="facebook/bart-large-cnn")

@app.get("/")
def home():
    return {"message": "BART Summarization API is Running!"}

@app.get("/summarize/")
def summarize(text: str):
    summary = summarizer(text, max_length=150, min_length=50, do_sample=False)
    return {"summary": summary[0]['summary_text']}

# Fix event loop issue in Google Colab
nest_asyncio.apply()

# Expose the API publicly using Ngrok
public_url = ngrok.connect(8000).public_url
print(f"Your Public API URL: {public_url}")

# Run FastAPI Server
uvicorn.run(app, host="0.0.0.0", port=8000)
# Out:
# ...
# Device set to use cpu
# Your Public API URL: https://0e43-34-48-125-62.ngrok-free.app
# INFO:     Started server process [189]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)
# INFO:     2401:4900:3b00:6243:6de0:8d96:4769:fee7:0 - "GET /summarize?text=AI+is+changing+the+world HTTP/1.1" 307 Temporary Redirect
# Your max_length is set to 150, but your input_length is only 7. Since this is a summarization task, where outputs shorter than the input are typically wanted, you might consider decreasing max_length manually, e.g. summarizer('...', max_length=3)
# INFO:     2401:4900:3b00:6243:6de0:8d96:4769:fee7:0 - "GET /summarize/?text=AI+is+changing+the+world HTTP/1.1" 200 OK
# INFO:     2401:4900:3b00:6243:6de0:8d96:4769:fee7:0 - "GET /favicon.ico HTTP/1.1" 404 Not Found
